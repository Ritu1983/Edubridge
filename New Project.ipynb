# %% [markdown]
# # CREDIT CARD FRAUD DETECTION

# %%
# IMPORT LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# LOAD THE DATA

data= pd.read_csv("creditcard.csv")

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
# TO CHECK THE INFORMATION

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# TO CHECK THE NULL VALUES

data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# TO CHECK THE SHAPE OF THE DATA

data.shape
# Out:
# (284807, 31)

# %%
# TO DESCRIBE THE DATA

data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
datac = data.copy()

# %%
# DATA IS GETTING UNEQUALLY DISTRIBUTED

sns.countplot(x='Class', data=datac, palette=['blue','red'])
plt.title('Unequally Distributed Classes', fontsize=15)                                          
plt.show()

# %%
# HEATMAP TO CHECK THE CORRELATION 

plt.figure(figsize=(14,9))
sns.heatmap(datac.corr(), annot=False, annot_kws={"size":6})

plt.show()

# %%
# TO APPLY THE STANDARD SCALER 

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
scale_time = ss.fit_transform(datac['Time'].values.reshape(-1,1))
scaled_amount = ss.fit_transform(datac['Amount'].values.reshape(-1,1))

time = datac.drop(['Time'], axis=1, inplace=True)
amount = datac.drop(['Amount'], axis=1, inplace=True)

datac.insert(0, "Scaled Time", scale_time)
datac.insert(0, "Scaled Amount", scaled_amount)

datac.head()
# Out:
#    Scaled Amount  Scaled Time        V1        V2        V3        V4  \
# 0       0.244964    -1.996583 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.342475    -1.996583  1.191857  0.266151  0.166480  0.448154
# 2       1.160686    -1.996562 -1.358354 -1.340163  1.773209  0.379780
# 3       0.140534    -1.996562 -0.966272 -0.185226  1.792993 -0.863291
# 4      -0.073403    -1.996541 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
scale_time
# Out:
# array([[-1.99658302],
#        [-1.99658302],
#        [-1.99656197],
#        ...,
#        [ 1.6419735 ],
#        [ 1.6419735 ],
#        [ 1.64205773]])

# %%
scaled_amount
# Out:
# array([[ 0.24496426],
#        [-0.34247454],
#        [ 1.16068593],
#        ...,
#        [-0.0818393 ],
#        [-0.31324853],
#        [ 0.51435531]])

# %%
# TO CHECK THE FIRST FIVE VALUES OF THE DATA SET

datac.head()
# Out:
#    Scaled Amount  Scaled Time        V1        V2        V3        V4  \
# 0       0.244964    -1.996583 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.342475    -1.996583  1.191857  0.266151  0.166480  0.448154
# 2       1.160686    -1.996562 -1.358354 -1.340163  1.773209  0.379780
# 3       0.140534    -1.996562 -0.966272 -0.185226  1.792993 -0.863291
# 4      -0.073403    -1.996541 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
# SEPERATING THE FRAUD AND NON-FRAUD VALUES

fraud = datac.loc[data['Class']==1]
non_fraud = datac.loc[data['Class']==0][:492]

# %%
# CONCATENATING THE FRAUD AND NON-FRAUD DATA

dataeq = pd.concat([fraud, non_fraud])

# %%
# TO CHECK THE LAST FIVE VALUES OF THE DATA SET

dataeq.tail()
# Out:
#      Scaled Amount  Scaled Time        V1        V2        V3        V4  \
# 487      -0.350231    -1.989065 -0.711928  1.547423  1.799759  2.489060
# 488      -0.283543    -1.989044  1.106251  0.398625  0.860421  2.388862
# 489      -0.186749    -1.989044 -0.424666  0.554293  1.374234 -0.447451
# 490      -0.348072    -1.989023  1.261597  0.256346  0.513254  0.619054
# 491      -0.349671    -1.989002  1.295406  0.296881  0.068725  0.572690
#
#            V5        V6        V7        V8  ...       V20       V21  \
# 487  0.450497  1.073762  0.309374  0.450854  ...  0.356887 -0.115133
# 488 -0.365843 -0.192568 -0.121769  0.150876  ... -0.200064 -0.253189
# 489  0.288248 -1.082536  0.969035 -0.347446  ...  0.240344 -0.023296
# 490 -0.472482 -0.989342  0.065431 -0.208781  ... -0.090150 -0.257305
# 491 -0.165698 -0.781113  0.030953 -0.133051  ... -0.105915 -0.330797
#
#           V22       V23       V24       V25       V26       V27       V28  \
# ...

# %%
# DATA IS GETTING EQUALLY DISTRIBUTED 

sns.countplot(x='Class', data=dataeq)
plt.title("Equally Distributed Classes", fontsize = 15)
plt.show()

# %%
# HEATMAP TO CHECK THE CORRELATION 

plt.figure(figsize=(15,7))
sns.heatmap(dataeq.corr(), annot=False, annot_kws = {"size": 6})
plt.show()

# %%
# TO CHECK THE POSITIVE CORRELATION THROUGH BOXPLOT

fig, axes = plt.subplots(ncols= 4, figsize=(20,4))

sns.boxplot(x='Class', y="V2", data=dataeq, ax=axes[0])
axes[0].set_title ("V2 vs Class (+ve Correlation)")

sns.boxplot(x='Class', y="V4", data=dataeq, ax=axes[1])
axes[1].set_title ("V4 vs Class (+ve Correlation)")

sns.boxplot(x='Class', y="V11", data=dataeq, ax=axes[2])
axes[2].set_title ("V11 vs Class (+ve Correlation)")

sns.boxplot(x='Class', y="V19", data=dataeq, ax=axes[3])
axes[3].set_title ("V19 vs Class (+ve Correlation)")

plt.show()

# %%
# TO CHECK THE NEGATIVE CORRELATION THROUGH BOXPLOT

fig, axes = plt.subplots(ncols= 4, figsize=(20,4))

sns.boxplot(x='Class', y="V3", data=dataeq, ax=axes[0])
axes[0].set_title ("V3 vs Class (-ve Correlation)")

sns.boxplot(x='Class', y="V10", data=dataeq, ax=axes[1])
axes[1].set_title ("V10 vs Class (-ve Correlation)")

sns.boxplot(x='Class', y="V12", data=dataeq, ax=axes[2])
axes[2].set_title ("V12 vs Class (-ve Correlation)")

sns.boxplot(x='Class', y="V14", data=dataeq, ax=axes[3])
axes[3].set_title ("V14 vs Class (-ve Correlation)")

plt.show()

# %%
# FUNCTION TO REMOVE THE OUTLIER

def rem_out(feature,data):
    fraud_array = data[feature].values
    q1 = np.percentile(fraud_array, 25)
    q3 = np.percentile(fraud_array, 75)
    iqr = q3-q1
    
    minimum = q1 - (1.5 * iqr)
    maximum = q3 + (1.5 * iqr)
    
    new_data = data.drop(data[(data[feature] < minimum) | (data[feature] > maximum)].index, axis=0)
    return new_data

# %%
# CALLING THE REM-OUT FUNCTION

new_data2 = rem_out('V2', dataeq)
new_data2 = rem_out('V3', new_data2)
new_data2 = rem_out('V10', new_data2)

# %%
#  BOXPLOT AFTER REMOVING THE OUTLIERS 

fig, axes = plt.subplots(ncols=3, figsize=(20,4))
sns.boxplot(x="Class", y="V2", data=new_data2, ax = axes[0])
axes[0].set_title('V2 vs Class (Positive Correlation)')

sns.boxplot(x="Class", y="V3", data=new_data2, ax = axes[1])
axes[1].set_title('V3 vs Class (Negative Correlation)')

sns.boxplot(x="Class", y="V10", data=new_data2, ax = axes[2])
axes[2].set_title('V10 vs Class (Negative Correlation)')
# Out:
# Text(0.5, 1.0, 'V10 vs Class (Negative Correlation)')

# %%
# COUNTPLOT TO SHOW DATA IS GETTING EQUALLY DISTRIBUTED 

sns.countplot(x='Class', data=new_data2)
plt.title("Newly Distributed Data", fontsize=15)
plt.show()

# %%
# APPLYING THE TRAIN_TEST_SPLIT

from sklearn.model_selection import train_test_split
x = new_data2.drop('Class',axis=1)
y = new_data2['Class']
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.3, random_state = 1)

# %%
from sklearn.metrics import f1_score,precision_score, recall_score, accuracy_score

# %%
y.head()
# Out:
# 541     1
# 623     1
# 4920    1
# 6108    1
# 6329    1
# Name: Class, dtype: int64

# %%
# 1) BUILD THE MODEL(LOGISTIC REGRESSION)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

f1 = f1_score(Y_test,y_pred)
precision=precision_score(Y_test,y_pred)
recall=recall_score(Y_test, y_pred)
accuracy = accuracy_score(Y_test, y_pred)

print("F1 Score: ", f1)
print("Precision: ", precision)
print("Recall: ", recall)
print("Accuracy: ", accuracy)
# Out:
# F1 Score:  0.9950738916256158
# Precision:  1.0
# Recall:  0.9901960784313726
# Accuracy:  0.996031746031746

# %%
# 2) BUILD THE MODEL(DECISION TREE)

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# PREDICTING THE DATA

y_pred_dtc=dtc.predict(X_test)

f1_dtc = f1_score(Y_test,y_pred_dtc)
precision_dtc=precision_score(Y_test,y_pred_dtc)
recall_dtc=recall_score(Y_test, y_pred_dtc)
accuracy_dtc = accuracy_score(Y_test, y_pred_dtc)

print("F1 Score: ", f1_dtc)
print("Precision: ", precision_dtc)
print("Recall: ", recall_dtc)
print("Accuracy: ", accuracy_dtc)
# Out:
# F1 Score:  0.9950738916256158
# Precision:  1.0
# Recall:  0.9901960784313726
# Accuracy:  0.996031746031746

# %%
# BUILD THE MODEL(NAIVE BAYES)

from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,Y_train)
# Out:
# F1 Score:  0.9760765550239235
# Precision:  0.9532710280373832
# Recall:  1.0
# Accuracy:  0.9801587301587301

# %%
# PREDICTING THE DATA

y_pred_nb=nb.predict(X_test)

f1_nb = f1_score(Y_test,y_pred_nb)
precision_nb=precision_score(Y_test,y_pred_nb)
recall_nb=recall_score(Y_test, y_pred_nb)
accuracy_nb = accuracy_score(Y_test, y_pred_nb)

print("F1 Score: ", f1_nb)
print("Precision: ", precision_nb)
print("Recall: ", recall_nb)
print("Accuracy: ", accuracy_nb)
# Out:
# F1 Score:  0.9760765550239235
# Precision:  0.9532710280373832
# Recall:  1.0
# Accuracy:  0.9801587301587301

# %%
#CONCLUSION ON THIS PROJECT:
    

After applying all the three algorithms (1. Logistic Regression, 2. Decision Tree Classifier, 3. GussianNB) 
we came to conclussion that the accuracy for all three algorithms are approximately same.
